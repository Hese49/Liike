# %%
# TEHTÄVIÄ

# DIM-1 TASAINEN LIIKE 

# s=?
t1 = 'Auto ajoi nopeudella 85km/h  5 h ajan. Kuinka pitkälle päästiin?'
       # 425 km
t2 = 'Kepa pyöräili mummolaan keskinopeutta 15 km/h ja matka kesti \
3 tuntia. Kuinka pitkä matka oli?' # 45 km
t3 = 'Kuinka kauas auto kulkee, kun se ajaa 3,4 h keskinopeudella 97 km/h?'
      #330 km
t4 = 'Markku ajaa 105 km/h nopeudella kolme tuntia. Kuinka kauas \
hän pääsee?' # 315 km
t5 = 'Hugo ajaa Ferrarilla 3 tuntia yhteen menoon. Kuinka kauas hän \
pääsee, kun hänen nopeutensa on 140 km/h?' # 420 km
t6 = 'Tervapääskyn lentonopeus on n. 30 m/s. Kuinka pitkän matkan \
tervapääsky lentää minuutissa?' # 1,8 km 
t7 = 'Auto kulkee 12 sekuntia nopeudella 15 m/s. Kuinka pitkän \
matkan auto kulkee?' #  180 m 
t8 = 'Kuinka pitkän matkan auto kulkee 2 minuutissa jos sen nopeus \
on 90 km/h?' # 3 km 
t9 = 'Matkustajakoneen nopeus on noin 900 km/h. kuinka pitkän matkan \
kone lentää yhdessä sekunnissa?' # 250 m        
t10 = 'Ranskassa TVG-junan matkanopeus on 270 km/h. Nopeasti likkuva \
jalankulkija ylittää kiskot neljässä sekunnissa. Kuinka pitkän matkan juna \
kulkee tänä aikana?' # 300 m
t11 = 'Kauppamatkustajan keskinopeus oli 12,5 m/s. Kuinka pitkä matka \
tällä nopeudella kuljetaan 180 sekunnissa?' #  2.25 km

# t=?
t12 = 'Maipin kävelynopeus on 3 km/h ja koulumatkan pituus on  \
6 kilometriä. Kauanko koulumatka kestää?'# 2h
t13 = 'Kotkasta Helsinkiin on 120 kilometriä. Kauanko matka Helsinkiin \
kestää, jos auton keskinopeus on 80 km/h?'# 1 h 30 min 
t14 = 'Kuinka kauan kestää ajaa 130 km nopeudella 84km/h?'# 1 h 33 min  
t15 = 'Markku haluaa ajaa 270 km nopeudella 105 km/h. Kuinka kauan \
hänen pitää ajaa?' # 2 h 34 min
t16 = 'Kuinka kauan aikaa kestää henkilöautolla ajaa 80 metriä, \
jos auton nopeus on 100 km/h?' # 2,9 s
t17 = 'Äänen nopeus ilmassa on 340 m/s. Kuinka kauan kestää äänen \
tuleminen 8000 metrin korkeudessa lentävästä lentokoneesta?' # 23,5 s
t18 = 'Syöksylaskijan nopeus on 63 km/h. Kuinka kauan aikaa kuluu \
häneltä 3 km:n matkaan?' # 2 min 51 s

# vk=?     keskinopeus = ? 
t19 = 'Junalta kului 300 km matkaan 5 tuntia, mikä oli junan nopeus?' # 60 km/h
t20 ='Kaverukset testasivat autonsa nopeusmittaria ajamalla 40 km/h \
mittarinopeudella. 100 metrin matkaan kului aikaa 10 s. \
Mikä oli mittauksen mukaan auton todellinen nopeus?'# 36 km/h
t21 ='Laske auton keskinopeus, kun 400 kilometrin matkaan \
kuluu aikaa 5 tuntia.'# 80 km/h
t22 ='Mikä oli pikajuoksija Usain Boltin keskinopeus, kun hän juoksi \
100 m aikaan 9,58 s?' # 37 km/h
t23 ='Helsingistä Pariisiin on matkaa 1900 kilometriä. \
Helsinki-Pariisi -lento kesti 3 tuntia. Laske lentomatkan keskinopeus.' # 634 km/h
t24 ='Satelliitin kiertoradan pituus on 260000 km ja satelliitti \
kiertää maapallon  vuorokaudessa. Laske satelliitin keskinopeus.' # 10836 km/h
t25 ='Gepardi (maailman nopein maaeläin) juoksi 113 metrin matkan \
4,5 sekunnissa. Laske gepardin keskinopeus.' # 90 km/h
t26 ='Mikä on liukuportaiden nopeus tavaratalossa, jos asiakkaalla \
menee 20,0 m pitkien portaiden avulla paikallaan seisten 16,0 s?' # 4 km/h
t27 ='Matti ja Maija ajavat mummolaan viikonlopuksi. Matkaa heillä \
on 320 km ja ajomatka kestää noin 4 tuntia. Mikä on heidän \
keskinopeutensa matkalla?' # 80 km/h
t28 ='Matti polkee kauppaan pyörällä. Matkaa on 5,5 km ja matka \
kestää häneltä noin puoli tuntia. Mikä on Matin keskinopeus matkalla \
kauppaan? Ilmoita vastaus kahden merkitsevän numeron tarkkuudella.' # 11 km/h
t29 = 'Rami ajeli Kokemäeltä Raumalle VOLVOLLA. Matkaa oli 62 km ja \
aikaa kului 45 min. Mikä oli Ramin/Volvon keskinopeus?'  # 83 km/h
t30 ='Auto ajaa 270 km kolmessa tunnissa. Mikä on auton nopeus?' # 90 km/h
t31 ='Jami ajaa  Pelloon Joutsenosta eli 920 km. Hän kuluttaa aikaa \
11 tuntia. Mikä on hänen keskinopeutensa?' # 84 km/h
t32 = 'Kuinka suuri nopeus on autolla, joka kulkee 70 metriä \
5 sekunnissa?' # 50 km/h

# --------------------------------------------------------------------------------------------------------------
# DIM-1 KIIHTYVÄ LIIKE 
# a=?
t33 = 'Auto liikkuu alkunopeudella 120 km/h ja jarruttaa \
pysähdyksiin 1,5 minuutin aikana. Mikä oli hidastuvuus?' # -0.4 m/s2
t34= 'Usain Bolt lähtee paikaltaan ja kiihdyttää neljässä sekunnissa \
nopeuteen 12m/s. Mikä on Usain Boltin kiihtyvyys?' # 3 m/s2
t35 = 'Kappale kiihdytetään 2 sekunnissa levosta nopeuteen 50 m/s. \
Laske kappaleen kiihtyvyys.' # 25 m/s2
t36  = 'Pyöräilijä ajaa nopeudella 20 km/h. Kun hän tulee alamäkeen \
hän 3 sekunnissa kiihdyttää nopeuteen 50 km/h. Laske kiihtyvyys.'# 2,8 m/s2 
t37 = 'Sähkömagneettisen raidetykkiä laukaistessa tykin ammusta \
kiihdytetään 0,0057 sekunnin ajan, jolloin se saavuttaa lähtönopeuden \
3,5 km/s. Laske tykin ammuksen kiihtyvyys.' # 614035 m/s2. 
t38 = 'Skootterin nopeus on 8 m/s ja 1,5 sekuntia kestävän jarrutuksen \
seurauksena se hidastuu nopeuteen 5 m/s. Laske skootterin \
keskikiihtyvyys.' # -2.0 m/s2  
t39 = 'Formula1 auto törmäsi rengasvalliin nopeudella 130 km/h, \
ja pysähtyi 0,14 sekunnissa. Laske kuljettajan ja auton \
keskikiihtyvyys.'# -258 m/s2   
t40 = 'Mikä on ammuksen kiihtyvyys 60 cm pitkässä kiväärin piipussa, \
kun se saa nopeuden 750 m/s?' # a = 4690  m/s2

#s=?
t41 = 'Autolla ajetaan nopeudella 80 km/h. Ohitustilanteessa kuski \
kiihdyttää kiihtyvyydellä  1,4 m/s2  4 sekunnin ajan kiihdytyksen \
aloittamisesta. Kuinka pitkä matka tänä aikana kuljettiin?' # 100 m
t42 ='Juna kiihdytti lähdöstä kiihtyvyydellä 0,6m/s2 15 s ajan. Kuinka kauas \
juna ehti tässä ajassa?' # 67.5 m
t43 ='Junan kiihtyvyys on 1,2 m/s2. Juna lähtee levosta ja kiihdyttää \
nopeuteen 72 km/h. Kuinka pitkän matkan juna kulkee tänä aikana?' # 166.7 m   
t44 ='Kuinka pitkän matkan kappale putoaa 3,5 sekunnissa?' # 60,1 m
t45 = 'Juna kiihdytti levosta vauhtiin 75 km/h 45 s aikana. Kuinka \
pitkän matkan juna kulki tänä aikana?' # 469 m 
t46 = 'Auto kiihdytti levosta vauhtiin 100 km/h 12 s aikana. Kuinka \
pitkän matkan auto kulki tänä aikana?' # 167 m 

#t=?
t47 ='Auton nopeus on 24 m/s. Jarruttaminen aiheuttaa tasaisen \
hidastuvuuden 4.0 m/s2. Kuinka kauan kestää auton pysäyttäminen?' # 6.0 s
t48 ='Auton keskikiihtyvyys on 5 m/s2. Kuinka monta sekuntia \
liikkeellelähdön jälkeen auto saavuttaa nopeuden 15 m/s?' # 3.0 s
t49 ='Kappale putoaa jyrkänteeltä maahan. Kuinka kauan putoaminen kestää, \
kun juuri ennen maahan osumista kappaleen nopeus on 40 m/s?' # 4,1 s
t50 ='Kuinka pitkän ajan kestää kappaleen kiihdyttäminen nollasta nopeuteen \
30 m/s, kun sen kiihtyvyys on 16 m/s2?' # 1,9 s
t51 ='Paljonko aikaa putoavalta kappaleelta kuluu 12 m putoamiseen?' # 1.6
t52 ='Auto kiihdytti levosta nopeuteen 100 km/h 155 m matkalla. \
Paljonko siihen kului aikaa?' # 11 s

# v0=?
t53  ='Mikä oli ylöspäin heitetyn kappaleen alkunopeus, kun se nousi \
2,4 m korkeuteen?' # 7 m/s
t54  =' Mikä oli ylöspäin heitetyn kappaleen alkunopeus, kun se nousi \
3,0 s ajan?' # 29.4 m/s

#v=?
t55 = 'Pallo heitetään suoraan ylöspäin alkuvauhdilla 12,8  m/s. \
Määritä pallon vauhti 1.6 s:n kuluttua heiton alusta.' # -2.9 m/s
t56 = 'Auto kiihdytti nopeudesta 3 m/s kiihtyvyydellä 0,5 m/s**2. \
mikä oli auton nopeus 6 s kuluttua?' # 6.0 m/s
t57 = 'Auton nopeus on 24 m/s. Jarruttaminen aiheuttaa tasaisen \
hidastuvuuden -4.0 m/s2. Mikä oli auton nopeus 3,0 s.n kuluttua \
jarrutuksen alusta?' # 43 km/h
t58 = 'Auton nopeus on 72 km/h. Sitä kiihdytetään 25 s keskimääräisellä \
kiihtyvyydellä 0,45 m/s2. Mikä on auton nopeus kiihdytyksen jälkeen?'
  # 112 km/h
t59 = 'Pallo heitetään suoraan ylöspäin alkunopeudella 12 m/s. \
Määritä pallon nopeus 0,5 s.n kuluttu  heiton alusta.' # 7.1 m/s
t60 = 'Kerrostaloasunnossa vietetään lauantai-iltana kotibileitä. \
Parvekkeella syntyy käsirysyä, jolloin eräs juhlijoista putoaa. \
Kuinka suurella nopeudella juhlija osuu maahan, kun hän tippuu \
kolmannesta kerroksesta (9,0 metrin korkeudesta)?' # 48 km/h
t61 = 'Auton keskikiihtyvyys on 5 m/s2. Mikä on auton nopeus kuusi sekunttia \
 liikkeellelähdön jälkeen?' # 108 km/h
t62 = 'Uimahyppääjä hyppää kymmenestä metristä. Oletetaan hänen \
alkunopeudekseen 0 m/s, aika ilmassa kestää 1,3 s. Mikä on uimahyppääjän \
nopeus hänen osuessaan veteen?' #  -12.8 m/s
t63 = 'Autolla ajetaan nopeudella 80 km/h. Ohitustilanteessa kuski \
kiihdyttää kiihtyvyydellä 1,4 m/s2. Mikä on auton nopeus 4 sekunnin \
kuluttua kiihdytyksen aloittamisesta?' # 100 km/h
t64 = 'Avaruussukkulan kantoraketin kiihdytysvaihe lähdöstä kestää  \
124 sekuntia ja sukkulan tasainen kiihtyvyys on n. 5,6 m/s2. Tässä \
vaiheessa rakettiosa irtoaa. Mihin loppunopeuteen sukkula pääsee?'
# 2500 km/h  "Millä korkeudella sukkula on tässä vaiheessa?" # 43.1km"
t65 = 'Fysiikan opiskelijoiden rakentama vesiraketti nousi pystysuoraan  \
120 metrin korkeuteen. Millä nopeudella se iskeytyi maahan?'# 175 km/h
t66 = 'Kivi putoaa jyrkänteeltä rotkoon. Putoaminen kestää 2,3 sekuntia. \
Mikä on kiven loppunopeus?' # -22,6 m/s 
t67 = 'Kappale putoaa Eiffel-tornista. Mikä nopeus kappaleella on \
2 sekunnin kuluttua?' # -19,62 m/s
t68 = 'Kuinka suuren nopeuden saa korkealta kielekkeeltä levosta \
putoava kivi 3 sekunnissa. Ilman vastus jätetään huomiotta.' # -29,4 m/s
t69 = 'Kappaleen alkunopeus on 5 m/s. Sitä kiihdytetään 3 sekunnin \
ajan kiihtyvyydellä 6 m/s2. Mikä on kappaleen loppunopeus?' # 83 km/h

#  HEITTO-/PUTOAMISLIIKKEITÄ (1-DIM)
t70 ='Kuinka pitkän matkan kappale putoaa 3,5 sekunnissa?' # 60,1 m
t71 ='Kappale putoaa jyrkänteeltä maahan. Kuinka kauan aikaa putoaminen \
kestää, kun juuri ennen maahan osumista kappaleen nopeus on 40 m/s?' # 4,1s
t72  ='Mikä oli ylöspäin heitetyn kappaleen alkunopeus, kun se nousi \
2,4 m korkeuteen?' # 6,9 m/s
t73  ='Mikä oli ylöspäin heitetyn kappaleen alkunopeus, kun se nousi \
3,0 s ajan?' # 29.4 m/s
t74 = 'Pallo heitetään suoraan ylöspäin alkuvauhdilla 12,8  m/s. \
Määritä pallon vauhti 1.6 s:n kuluttua heiton alusta' # -2.9 m/s
t75 = 'Pallo heitetään suoraan ylöspäin alkunopeudella 12 m/s. \
Määritä pallon nopeus 0,5 s.n kuluttu  heiton alusta.' # 7.1 m/s
t76 = 'Kerrostaloasunnossa vietetään lauantai-iltana kotibileitä. \
Parvekkeella syntyy käsirysyä, jolloin eräs juhlijoista putoaa. \
Kuinka suurella nopeudella juhlija osuu maahan, kun hän tippuu \
kolmannesta kerroksesta (9,0 metrin korkeudesta)?' # 48 km/h
t77 = 'Uimahyppääjä hyppää kymmenestä metristä. Oletetaan hänen \
alkunopeudekseen 0 m/s, aika ilmassa kestää 1,3 s. Mikä on uimahyppääjän \
nopeus hänen osuessaan veteen?' #  -12.8 m/s
t78 = 'Fysiikan opiskelijoiden rakentama vesiraketti nousi pystysuoraan  \
120 metrin korkeuteen. Millä nopeudella se iskeytyi maahan?' # 175 km/h
t79 = 'Kivi putoaa jyrkänteeltä rotkoon. Putoaminen kestää 2,3 sekuntia. \
Mikä on kiven loppunopeus?' # -22,6 m/s 
t80 = 'Kappale putoaa Eiffel-tornista. Mikä nopeus kappaleella on  \
2 sekunnin kuluttua?' # -19,6 m/s
t81 = 'Kuinka suuren nopeuden saa korkealta kielekkeeltä levosta \
putoava kivi 3 sekunnissa. Ilman vastus jätetään huomiotta.' # -29,4 m/s
t82 = 'Pallo heitetään suoraan ylöspäin alkunopeudella 12 m/s. \
Määritä pallon nousuaika.' # 1.2 s
t83 = 'Pallo heitetään suoraan ylöspäin alkunopeudella 12 m/s. \
Määritä nopeus 0,5 s kuluttua  heiton alusta.' # 7.1 m/s
t84 ='Milloin alkunopeudella 3.2 m/s ylöspäin heitetty \
kappale palaa maahan.' # 0.7 s 
t85 ='Mikä oli ylöspäin heitetyn kappaleen alkunopeus, kun se palasi \
maahan 4,5 s kuluttua?' # 22.1 m/s
t86 = 'Luistelijan pystysuuntainen lähtönopeus on 3,4 m/s ja lentoaika \
0,36s. Laske korkeus, jolle taitoluistelija voi tässä tilanteessa hypätä.'
 # 0.6 m
t87='Junan kiihtyvyys on 1,2 m/s2. Juna lähtee levosta ja kiihdyttää \
kiihdyttää nopeuteen 72 km/h. Kuinka kauan kiihdytys kestää?' # 16.7 s
t88='Junan kiihtyvyys on 1,2 m/s2. Juna lähtee levosta ja \
 nopeuteen 72 km/h. Kuinka pitkän matkan juna kulkee tänä aikana?' # 167 m. 
t89 = 'Avaruussukkulan kantoraketin kiihdytysvaihe lähdöstä kestää 124 sekuntia \
ja sukkulan tasainen kiihtyvyys on n. 5,6 m/s2. Tässä vaiheessa rakettiosa \
irtoaa. Mihin loppunopeuteen sukkula pääsee rakettinsa avulla?'  # 2500 km/h 
t90 = 'Avaruussukkulan kantoraketin kiihdytysvaihe lähdöstä kestää 124 sekuntia \
ja sukkulan tasainen kiihtyvyys on n. 5,6 m/s2. Tässä vaiheessa rakettiosa \
irtoaa. Millä korkeudella sukkula on tässä vaiheessa?' # 43.1 km
t91 = 'Pallo heitetään suoraan ylöspäin alkunopeudella 12 m/s. \
Määritä pallon nousuaika.' # 1.2 s
t92 = 'Pallo heitetään suoraan ylöspäin alkunopeudella 12 m/s. \
Määritä nopeus 0,5 s.n kuluttu heiton alusta.' # 7.1 m/s 
t93 = 'Jarmo ja Erja keskustelevat. Jarmo sanoo kiihdyttäneensä  \
viritetyn moponsa paikaltaan nopeuteen 40 km/h 12 sekunnissa. \
Laske kiihtyvyys.' # 0.9 m/s2
t94 =  'Erja taas sanoi kiihdyttäneensä moponsa paikaltaan  \
nopeuteen 50 km/h 15 sekunnissa. Laske kiihtyvyys.' # 0.9 m/s2

# SEKALAISIA
t95 = 'Kappale heitetään ylöspäin alkunopeudella 12 m/s. Milloin \
se palaa maahan?' # 2.4 s  
t96  ='Mikä oli ylöspäin heitetyn kappaleen alkunopeus, kun se palasi \
maahan 4,5 s kuluttua?' # 22.1 m/s
t97 = 'Nopeusmittarin tarkistamiseksi ajettiin tasan kilometrin \
matka, johon kului aikaa 48 s. Auton nopeusmittari näytti koko ajan \
80 km/h. Paljonko auton nopeusmittari valehtelee ja kumpaan suuntaan?'
# keskinopeus oli 75 km/h
t98 ='Gepardi (maailman nopein maaeläin) juoksi 113 metrin matkan \
4,5 sekunnissa. Laske gepardin keskinopeus.' # 90 km/h
t99 ='Matti polkee kauppaan pyörällä. Matkaa on 5,5 km ja matka \
kestää häneltä noin puoli tuntia. Mikä on Matin keskinopeus matkalla \
kauppaan?' # 11 km/h
t100 ='Auto ajaa nopeudella 100 km/h suoralla tiellä. Nopeusrajoitusmerkin \
nähdessään autoilija jarruttaa kiihtyvyydellä -1,85 m/s2 kolmen sekunnin \
 ajan. Laske alennettu nopeusrajoitus olettaen,\
että kuskin loppunopeus on rajoituksen mukainen.'
# 80 km/h  
t101 ='Burj Khalifa on maailman korkein rakennus. Se on 828 metriä korkea. \
Ilmanvastusta ei oteta laskuissa huomioon. Samppanjapullo pudotetaan \
huipulta. Kuinka kauan putoaminen kestää?' # 13.0 s
t102 = 'Auton vauhti kasvaa 150 m matkalla nopeudesta 15 km/h nopeuteen 80 km/h. Laske auton kiihtyvyys.'
# 1.6 m/s2

dim1=(t1,t2,t3,t4,t5,t6,t7,t8,t9,t10,t11,t12,t13,t14,t15,t16,t17,t18,t19,
t20,t21,t22,t23,t24,t25,t26,t27,t28,t29,t30,t31,t32,t33,t34,t35,t36,t37,
t38,t39,t40,t41,t42,t43,t44,t45,t46,t47,t48,t49,t50,t51,t52,t53,t54,t55,
t56,t57,t58,t59,t60,t61,t62,t63,t64,t65,t66,t67,t68,t69,t70,t71,t72,t73,
t74,t75,t76,t77,t78,t79,t80,t81,t82,t83,t84,t85,t86,t87,t88,t89,t90,t91,
t92,t93,t94,t95,t96,t97,t98,t99,t100,t101,t102)

'''
# Kaikki dim1 ajot kerralla:
    for index, kys in enumerate(dim1):  
        vastaus = AJO1(i)
        print(index+1, vastaus)   
'''
# Out:
# '\n# Kaikki dim1 ajot kerralla:\n    for index, kys in enumerate(dim1):  \n        vastaus = AJO1(i)\n        print(index+1, vastaus)   \n'

# %%
# VINO HEITTOLIIKE
'Pallo heitetään 45 asteen kulmassa. Kuinka kauas pallo lentää?'  # Ei riitävästi tietoa!

vi1 = 'Näsinneulan 120 m tasanteelta heitetään pallo vaakasuoraan \
alkunopeudella 20 m/s. Kuinka kauaksi pallo putoaa vaakasuoraksi \
oletetulle maanpinnalle?'
#   98.9 m 
vi2 = 'Näsinneulan 120 m tasanteelta heitetään pallo vaakasuoraan \
alkunopeudella 20 m/s. Missä kulmassa pallo kohtaa maan pinnan?'
#  -67.6 astetta
vi3 = 'Kivi heitetään 45 m korkeasta tornista vaakasuoraan \
nopeudella 20 m/s. Kuinka etäällä kivi kohtaa vaakasuoran maanpinnan?'
#  60.6 m
vi4 = 'Kivi heitetään 45 m korkeasta tornista vaakasuoraan \
nopeudella 20 m/s. Mikä on kiven nopeus, kun se kohtaa maanpinnan?' 
#  35.8 m/s
vi5 = 'Pesäpallo lyödään laakana alkunopeudella 19 m/s korkeudelta \
1,5 m. Missä kohtaa pallo osuu maahan, kun ilmavastusta ei oteta huomioon, \
eikä kukaan saa sitä kiinni?'
#  10.5 m 
vi6 = 'Pesäpallo lyödään laakana alkunopeudella 19 m/s korkeudelta \
1,5 m. Millä nopeudella pallo osuu maahan?' 
#  19.8 m/s
vi7 = 'Kiväärin kuula ammutaan vaakasuoraan nopeudella 750 m/s. \
Maali on 200 m päässä. Kuinka paljon kuula putoaa tällä matkalla?'
#  -0.349 m   
vi8 = 'Uskalias uimari juoksee kallionkielekkeeltä ja hyppää veteen \
vaakasuoralla alkunopeudella. Millä alkunopeudella hänen on juostava, \
jotta hän välttää 9 metriä lähtötason alla olevan 1,75 metriä leveän \
kallionkielekkeen?'  # 1.3 m/s 
vi9 = 'Lentokoneen vaakasuoraan nopeudella 205 m/s. Koneesta pudotettu \
pieni punnus osuu maahan 11,2 sekunnissa. Laske punnuksen pudotuskorkeus. \
Ilmanvastusta ei huomioida.'  #  615 m,
vi10 = 'Lentokoneen vaakanopeus oikealle on 205 m/s. Koneesta \
pudotettu pieni punnus osuu maahan 11,2 sekunnissa. Ilmanvastusta ei \
tarvitse huomioida. Laske punnuksen vaakasuora lentomatka.'  # 2300 m
vi11 = 'Lentokoneen vaakanopeus oikealle on 205 m/s. Koneesta \
pudotettu pieni punnus osuu maahan 11,2 sekunnissa. Laske laske \
punnuksen nopeus, kun se osuu maahan. Ilmanvastusta ei tarvitse huomioida.'
#233 m/s 
vi12 = 'Lentokoneen vaakanopeus oikealle on 205 m/s. Koneesta \
pudotettu pieni punnus osuu maahan 11,2 sekunnissa. Ilmanvastusta ei \
tarvitse huomioida. Laske laske punnuksen suunta, kun se osuu maahan.'
# -28 astetta.
vi13 = ' Vaakasuoraan nopeudella 600 km/h lentävä pommikone pudottaa \
pommin, joka osuu maahan 45 asteen kulmassa. Laske koneen korkeus pudotushetkellä.'
# 1420 m  Huom. ei siedä 'Vaaka... pitää olla ' Vaaka.. tai ilman ylä pilkkua
vi14 = 'Pallo potkaistaan maanpinnasta 39,0 asteen kulmassa. Pallon \
alkunopeus on 14,1 m/s. Lopuksi pallo osuu maahan, eikä ilmanvastusta \
tarvitse huomioida. Laske  pallon lentoaika.' # 1.8 s
vi15= 'Pallo potkaistaan maanpinnasta 39,0 asteen kulmassa. Pallon \
alkunopeus on 14,1 m/s. Lopuksi pallo osuu maahan, eikä ilmanvastusta \
tarvitse huomioida. Laske pallon lakikorkeus.' # 4.01 m
vi16 = 'Pallo potkaistaan maanpinnasta 39,0 asteen kulmassa. Pallon \
alkunopeus on 14,1 m/s. Lopuksi pallo osuu maahan, eikä ilmanvastusta \
tarvitse huomioida. Laske pallon kantama.'    # 19.8 m
vi17 = 'Kiväärin luoti ammutaan alkunopeudella 750 m/sekunnissa. \
Lähtösuunta muodostaa 30 asteen kulman vaakatason kanssa. Määritä \
lentomatka.'  # 49700 m
vi18 = 'Kiväärin luoti ammutaan alkunopeudella 750 m/sekunnissa. \
Lähtösuunta muodostaa 30 asteen kulman vaakatason kanssa. Määritä \
nousukorkeus lähtöhetkestä lukien.' #7170m
vi19 = 'Kiväärin luoti ammutaan alkunopeudella 750 m/sekunnissa. \
Lähtösuunta muodostaa 30 asteen kulman vaakatason kanssa. Määritä \
luodin paikka 4 s kuluttua.' # x=2600 m  y=1420 m
vi20 = 'Yleisurheilun GP – kisojen miesten kuulan voittotyönnössä \
kuula lähti 180 cm korkeudelta 45 asteen kulmassa lähtönopeudella \
14.10 m/s. Kuinka pitkälle työntö kantoi?' # 21.9 m                          
vi21 = 'Raketti ammutaan 70 asteen kulmassa vaakatasoon nähden \
alkunopeudella 350 m/s. Ilmanvastusta ei oteta huomioon. \
Millä ajanhetkellä raketti on lakikorkeudessa?' # 33.5 s 
vi22 = 'Raketti ammutaan 70 asteen kulmassa vaakatasoon nähden \
alkunopeudella 350 m/s. Kuinka korkealle raketti lensi?' # 5520 m
vi23 = 'Raketti ammutaan 70 asteen kulmassa vaakatasoon nähden \
alkunopeudella 350 m/s. Kuinka pitkään raketti oli ilmassa?' # 67 s  
vi24 = 'Raketti ammutaan 70 asteen kulmassa vaakatasoon nähden \
alkunopeudella 350 m/s. Kuinka kauas raketti lensi?' # 8030m       
vi25 = 'Tykillä ammutaan 175 m korkean kukkulan huipulta 30 asteen \
korotuksella lähtönopeudella 400 m/s.  Missä ajassa ammus kohtaa vuoren \
juuren tasolla olevan maalin?' # 41.6 s, 
vi26 ='Tykillä ammutaan 175 m korkean kukkulan huipulta 30 asteen \
korotuksella lähtönopeudella 400 m/s. Mikä on ammuksen nopeus sen \
saapuessa  maaliin?' # 404 m/s
vi27 ='Tykillä ammutaan 175 m korkean vuoren huipulta 30 asteen \
korotuksella lähtönopeudella 400 m/s. Missä kulmassa se saapuu maahan?'
# -31 astetta
vi28 = 'Eräs EM-kisojen kilpailija työnsi harjoituksissa kuulaa 18,0 m. \
Kuulan lähtökulma oli 45 astetta ja lähtökorkeus maanpinnasta 2,0 m. \
Kuinka suuri oli kuulan lähtönopeus?' # 12.6 m/s 
vi29 = 'Eräs EM-kisojen kilpailija työnsi harjoituksissa kuulaa 18,0 m. \
Kuulan lähtökulma oli 45 astetta ja lähtökorkeus maanpinnasta 2,0 m. \
Millä nopeudella kuula osui maahan?' #14.1 m/s                            
vi30 = 'Ilmatorjuntatykin kranaatin lähtönopeus on 600 m/s ja \
lähtökulma 60 astetta. Kranaatti on säädetty räjähtämään 6,0 s kuluttua \
laukaisusta. Kuinka korkealla lentävät torjunnan kohteena olevat \
lentokoneet?' # 2941 m 
vi31 = 'Rannikkotykistön ammunnoissa eräs tykinammus lähtee nopeudella \
600 m/s kulmaan 25 astetta. Laske ammuksen lentoaika.' # 51.7 s
vi32 = 'Rannikkotykistön ammunnoissa eräs tykinammus lähtee nopeudella \
600 m/s kulmaan 25 astetta. Laske kantama.' # 28100 m
vi33 = 'Rannikkotykistön ammunnoissa eräs tykinammus lähtee nopeudella \
600 m/s kulmaan 25 astetta. Laske lakikorkeus.' # 3280 m
vi34 = 'Antti seisoo 15 m korkean rakennuksen katolla ja heittää \
kiven nopeudella 30 m/s suuntaan, joka osoittaa 33,0 astetta \
vaakatason yläpuolelle. Laske kiven saavuttama maksimikorkeus \
katosta mitattuna.'#  13.6 m 
vi35 = 'Antti seisoo 15 m korkean rakennuksen katolla ja heittää \
kiven nopeudella 30 m/s suuntaan, joka osoittaa 33,0 astetta \
vaakatason yläpuolelle. Laske kiven vauhti juuri ennen sen osumista maahan.'
# 34.5 m/s
vi36 = 'Antti seisoo 15 m korkean rakennuksen katolla ja heittää \
kiven nopeudella 30 m/s suuntaan, joka osoittaa 33,0 astetta \
vaakatason yläpuolelle. Laske kiven osumiskohdan vaakasuora \
etäisyys heittopaikasta.' # 103 m
vi37= 'Keihäs heitetään 2,0 m korkeudelta 30 asteen kulmassa maan \
pintaan nähden. Keihäs lentää 42 m päähän. Määritä keihään alkunopeus.'
# 21 m/s
vi38 = 'Pommikone syöksyy nopeudella 720 km/h ja pudottaa pommin 400 m \
korkeudelta. Määritä tarvittava maaliennakko, kun koneen suunta \
muodostaa -30 asteen kulman vaakatason kanssa.' # 593 m
vi39 = 'Kaksi pesäpalloilijaa harjoittelee heittoja. Kuinka korkealla \
lähtötasosta pallo käy, kun lentoaika on 2 s?' # 4.91 m 
vi40 ='Kuula lähti alkunopeudella 12.0 m/s kulmassa 60 astetta 180 cm \
korkeudelta. Laske kuulan paikka 1.5 s kuluttua?' #x:9.0 m y: 6.35 m          
vi41 ='Kuula lähti alkunopeudella 12.0 m/s kulmassa 60 astetta 180 cm \
korkeudelta. Kuinka pitkälle kuula lensi?' # 13.7 m
vi42 = 'Yleisurheilun GP – kisojen miesten kuulan voittotyönnössä \
kuula lähti 180 cm korkeudelta 45 asteen kulmassa ja  lensi 21.9 m päähän. \
Mikä oli kuulan lähtönopeus?' # 14.1 m/s

dim2_tehtävät = (vi1,vi2,vi3,vi4,vi5,vi6,vi7,vi8,vi9,vi10,
       vi11,vi12,vi13,vi14,vi15,vi16,vi17,vi18,vi19,vi20,
       vi21,vi22,vi23,vi24,vi25,vi26,vi27,vi28,vi29,vi30,
       vi31,vi32,vi33,vi34,vi35,vi36,vi37,vi38,vi39,vi40,vi41,42)
